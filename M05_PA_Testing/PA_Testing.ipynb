# %% [raw]
# # Stephen Garcia Perez
# # Programming Assignments - Testing
# # This is all the code from the "Getting Started With Testing in Python Programming Assignment" with the file names on top. They will be put together in the GitHub as well.

# %% [raw]
# test_sum.py

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "should be 6"
    
if __name__ == "__main__":
    test_sum()
    print("Everything passed")
# Out:
# Everything passed

# %% [raw]
# test_sum_2.py

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    test_sum_tuple()
    print("Everything passed")

# %% [raw]
# test_sum_unittest.py

# %%
import unittest

class TestSum(unittest.TestCase):
    
    def test_sum(self):
        self.assertEqual(sum([1, 2, 3]), 6, "Should be 6")

    def test_sum_tuple(self):
        self.assertEqual(sum((1, 2, 2)), 6, "Should be 6")
        
if __name__ == "__main__":
    unittest.main()

# %% [raw]
# Directory: "project"

# %% [raw]
#     sub_directory: my_sum

# %% [raw]
#     __init__.py

# %%
def sum(arg):
    total = 0
    for val in arg:
        total += val
    return total

# %% [raw]
# Under the "project" directory

# %% [raw]
# test.py

# %%
from fractions import Fraction
import unittest

from my_sum import sum

class testSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)
        
    def test_list_fraction(self):
        """
        Test that it can sum a list of fractions
        """
        data = [Fraction(1, 4), Fraction(1, 4), Fraction(2, 5)]
        result = sum(data)
        self.assertEqual(result, 1)
        
if __name__ == "__main__":
    unittest.main()

# %% [raw]
# The tests result indicate wether the test has either failed to meet the assertion or the script itself met the requirements for the program to succeed in whatever the case is.
#
# For example, adding integers to a list by passing them to a function/method, then inside the function adding all the values together by itirating through the list, and checking if that number is greater than whatever value we have set. Basically checking wether our program meets the actions we want to perform, as long as we set the correct test script for it.
