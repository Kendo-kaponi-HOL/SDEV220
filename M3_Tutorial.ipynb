# %% [markdown]
# This is the code in VS code

# %%
def sort_it(arr):
    
    low, mid, high = 0, 0, len(arr) - 1
        
    while mid <= high:
        if arr[mid] == 0:
            arr[low], arr[mid] = arr[mid], arr[low]
            low += 1
            mid += 1
        elif arr[mid] == 1:
            mid += 1
        else:  # arr[mid] == 2
            arr[mid], arr[high] = arr[high], arr[mid]
            high -= 1
        
    return arr

if __name__ == "__main__":
    arr = [0, 1, 2, 2, 2, 1, 0, 2, 0, 1, 2]
    new_arr = sort_it(arr)

    print(new_arr)

# %% [markdown]
# This is the code in their website

# %%
class Solution:
    def sort012(self, arr):
        # code here
        low, mid, high = 0, 0, len(arr) - 1
        
        while mid <= high:
            if arr[mid] == 0:
                arr[low], arr[mid] = arr[mid], arr[low]
                low += 1
                mid += 1
            elif arr[mid] == 1:
                mid += 1
            else:  # arr[mid] == 2
                arr[mid], arr[high] = arr[high], arr[mid]
                high -= 1
        
        return arr

# %% [markdown]
# Binary Search

# %% [markdown]
# This is the code in VS code

# %%
arr = [1, 2, 4, 4, 4, 5, 7, 7, 9]
k = 4


def binary_search(arr, k):
    low = 0
    high = len(arr) - 1
    first_index = -1

    while low <= high:
        mid = (low + high) // 2

        if arr[mid] == k:
            first_index = mid 
            high = mid - 1        
        elif k < arr[mid]:
            high = mid - 1
        else:
            low = mid + 1

    return first_index

index = binary_search(arr, k)

print(index)

# %% [markdown]
# This is the code in their website

# %%
class Solution:
    def binarysearch(self, arr, k):
        # Code Here
        low = 0
        high = len(arr) - 1
        first_index = -1

        while low <= high:
            mid = (low + high) // 2

            if arr[mid] == k:
                first_index = mid
                high = mid - 1
            elif k < arr[mid]:
                high = mid - 1
            else:
                low = mid + 1

        return first_index

        index = binarysearch(arr, k)
        print(index)
